# %%
from pathlib import Path

import pandas as pd
import geopandas as gpd
from tqdm import tqdm

# %% [markdown]
# # Load surveys

# %%
raw_dir = Path('../data/dhs/raw')

# %%
GEO_COLS = ['DHSYEAR', 'DHSCLUST', 'URBAN_RURA', 'LATNUM', 'LONGNUM', 'DATUM', 'geometry', 'yes', 'no']
SURVEY_COLUMNS = ['hv001', 'hv206']
hr_dfs = dict()

for year_dir in tqdm(raw_dir.iterdir()):
    if year_dir.is_dir():
        year = year_dir.name[3:7]
        for dataset_type_dir in year_dir.iterdir():
            dataset_type = dataset_type_dir.stem[2:4]
            if dataset_type == 'HR':
                for file in dataset_type_dir.iterdir():
                    if file.suffix == '.DTA':
                        survey_df = pd.read_stata(file, columns=SURVEY_COLUMNS)
            """if dataset_type == 'GE':
                for file in dataset_type_dir.iterdir():
                    if file.suffix == '.shp':
                        geo_df = gpd.read_file(file)"""
        survey_df['hv206'] = survey_df['hv206'].str.lower()
        survey_df = survey_df.groupby('hv001')['hv206'].value_counts().unstack()
        #df = geo_df.merge(survey_df, how='outer', left_on='DHSCLUST', right_on='hv001')
        #df[GEO_COLS].to_file(f'{year}.shp')
        #hr_dfs[year] = df[GEO_COLS].copy()
        hr_dfs[year] = survey_df[SURVEY_COLUMNS]
# Out:
# 0it [00:03, ?it/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-c8dfe0ec1dfe> in <module>
#      21         #df[GEO_COLS].to_file(f'{year}.shp')
#      22         #hr_dfs[year] = df[GEO_COLS].copy()
# ---> 23         hr_dfs[year] = survey_df[SURVEY_COLUMNS]
#
# ~/.local/share/virtualenvs/bachelor_project-wo29InNu/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# ~/.local/share/virtualenvs/bachelor_project-wo29InNu/lib/python3.8/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1550             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1551
# -> 1552         self._validate_read_indexer(
#    1553             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1554         )
#
# ~/.local/share/virtualenvs/bachelor_project-wo29InNu/lib/python3.8/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1638             if missing == len(indexer):
#    1639                 axis_name = self.obj._get_axis_name(axis)
# -> 1640                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1641
#    1642             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [Index(['hv001', 'hv206'], dtype='object', name='hv206')] are in the [columns]"

# %% [markdown]
# `hv001` is cluster, `hv206` is whether or not there is electricity.

# %%
hr_dfs['2008']
# Out:
#      DHSYEAR  DHSCLUST URBAN_RURA    LATNUM  LONGNUM  DATUM  \
# 0     2008.0       1.0          U  13.20103  6.37771  WGS84
# 1     2008.0       2.0          U  13.08147  5.26264  WGS84
# 2     2008.0       3.0          U  13.06933  5.23022  WGS84
# 3     2008.0       4.0          R  13.11720  4.94252  WGS84
# 4     2008.0       5.0          R  12.84140  5.09136  WGS84
# ..       ...       ...        ...       ...      ...    ...
# 881   2008.0     884.0          R   6.76871  3.64365  WGS84
# 882   2008.0     885.0          R   6.70765  3.48796  WGS84
# 883   2008.0     886.0          R   7.23515  3.00508  WGS84
# 884   2008.0     887.0          R   7.19138  2.96943  WGS84
# 885   2008.0     888.0          R   6.85844  3.03110  WGS84
#
#                      geometry   yes    no
# 0    POINT (6.37771 13.20103)  34.0   4.0
# 1    POINT (5.26264 13.08147)  37.0   1.0
# 2    POINT (5.23022 13.06933)  40.0   NaN
# 3    POINT (4.94252 13.11720)   4.0  33.0
# 4    POINT (5.09136 12.84140)   NaN  41.0
# ..                        ...   ...   ...
# 881   POINT (3.64365 6.76871)   1.0  40.0
# 882   POINT (3.48796 6.70765)  22.0  19.0
# 883   POINT (3.00508 7.23515)  18.0  16.0
# 884   POINT (2.96943 7.19138)   NaN  38.0
# 885   POINT (3.03110 6.85844)  39.0   1.0
#
# [886 rows x 9 columns]
